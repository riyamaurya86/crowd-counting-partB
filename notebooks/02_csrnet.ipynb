# %%
# !git clone https://github.com/riyamaurya86/crowd-counting-partB.git
# Out:
# Cloning into 'crowd-counting-partB'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 79 (delta 29), reused 69 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 23.03 MiB | 38.97 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# %cd crowd-counting-partB
# Out:
# /kaggle/working/crowd-counting-partB

# %%
import os
import torch
from torch.utils.data import DataLoader

from src.datasets.shanghai_partb import ShanghaiPartBDataset
from src.models.csrnet import CSRNet
from src.engine.trainer import train_one_epoch, validate, save_checkpoint
from src.losses.mse import get_mse_loss
from src.utils.seed import set_seed

# %%
set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
dataset_path = "/kaggle/input/datasets/tthien/shanghaitech-with-people-density-map/ShanghaiTech/part_B"

train_dataset = ShanghaiPartBDataset(dataset_path, mode="train", crop_size=256)
test_dataset = ShanghaiPartBDataset(dataset_path, mode="test")

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=2)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))
# Out:
# Train size: 400
# Test size: 316

# %%
model = CSRNet(pretrained=True).to(device)

criterion = get_mse_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
num_epochs = 50
best_mae = float("inf")

os.makedirs("checkpoints/cnn", exist_ok=True)

for epoch in range(num_epochs):
    print(f"\nEpoch [{epoch+1}/{num_epochs}]")

    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_results = validate(model, test_loader, criterion, device)

    print(f"Train Loss: {train_loss:.6f}")
    print(f"Val MAE: {val_results['mae']:.2f}")
    print(f"Val RMSE: {val_results['rmse']:.2f}")
    print(f"Val PSNR: {val_results['psnr']:.2f}")
    print(f"Val SSIM: {val_results['ssim']:.4f}")

    # Save best model
    if val_results["mae"] < best_mae:
        best_mae = val_results["mae"]
        best_results = val_results.copy()
        save_checkpoint(
            model,
            optimizer,
            epoch,
            best_mae,
            "checkpoints/csrnet/best_model.pth"
        )
# Out:
# Epoch [1/50]
# Training: 100%|██████████| 25/25 [00:09<00:00,  2.52it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.94it/s]
# Train Loss: 0.000001
# Val MAE: 186.46
# Val RMSE: 205.45
# Val PSNR: 27.20
# Val SSIM: 0.4122
#
# Epoch [2/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.42it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.95it/s]
# Train Loss: 0.000001
# Val MAE: 104.12
# Val RMSE: 130.72
# Val PSNR: 28.40
# Val SSIM: 0.4961
#
# Epoch [3/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.47it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.98it/s]
# Train Loss: 0.000001
# Val MAE: 58.17
# Val RMSE: 74.83
# Val PSNR: 28.68
# Val SSIM: 0.5452
#
# Epoch [4/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.45it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.07it/s]
# Train Loss: 0.000000
# Val MAE: 41.73
# Val RMSE: 65.09
# Val PSNR: 28.90
# Val SSIM: 0.5476
#
# Epoch [5/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.42it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 44.49
# Val RMSE: 64.17
# Val PSNR: 29.04
# Val SSIM: 0.5573
#
# Epoch [6/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.37it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 34.81
# Val RMSE: 60.19
# Val PSNR: 29.14
# Val SSIM: 0.5460
#
# Epoch [7/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.32it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 61.73
# Val RMSE: 73.38
# Val PSNR: 29.13
# Val SSIM: 0.5662
#
# Epoch [8/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.15it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.07it/s]
# Train Loss: 0.000001
# Val MAE: 52.08
# Val RMSE: 72.04
# Val PSNR: 29.26
# Val SSIM: 0.5324
#
# Epoch [9/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.31it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 34.73
# Val RMSE: 53.54
# Val PSNR: 29.54
# Val SSIM: 0.5748
#
# Epoch [10/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.51it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.07it/s]
# Train Loss: 0.000000
# Val MAE: 29.91
# Val RMSE: 50.94
# Val PSNR: 29.85
# Val SSIM: 0.5882
#
# Epoch [11/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.45it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.04it/s]
# Train Loss: 0.000000
# Val MAE: 38.60
# Val RMSE: 54.69
# Val PSNR: 30.00
# Val SSIM: 0.6056
#
# Epoch [12/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.48it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.00it/s]
# Train Loss: 0.000000
# Val MAE: 28.42
# Val RMSE: 49.40
# Val PSNR: 30.09
# Val SSIM: 0.6061
#
# Epoch [13/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.48it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.01it/s]
# Train Loss: 0.000000
# Val MAE: 29.41
# Val RMSE: 48.06
# Val PSNR: 30.12
# Val SSIM: 0.6101
#
# Epoch [14/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.47it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 60.22
# Val RMSE: 68.91
# Val PSNR: 29.78
# Val SSIM: 0.6115
#
# Epoch [15/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.53it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.93it/s]
# Train Loss: 0.000001
# Val MAE: 77.03
# Val RMSE: 82.51
# Val PSNR: 29.83
# Val SSIM: 0.6066
#
# Epoch [16/50]
# Training: 100%|██████████| 25/25 [00:09<00:00,  2.65it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.96it/s]
# Train Loss: 0.000001
# Val MAE: 58.29
# Val RMSE: 68.86
# Val PSNR: 29.85
# Val SSIM: 0.6131
#
# Epoch [17/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.45it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.02it/s]
# Train Loss: 0.000000
# Val MAE: 27.15
# Val RMSE: 41.80
# Val PSNR: 30.43
# Val SSIM: 0.6277
#
# Epoch [18/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.50it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.03it/s]
# Train Loss: 0.000000
# Val MAE: 55.00
# Val RMSE: 66.06
# Val PSNR: 29.86
# Val SSIM: 0.6275
#
# Epoch [19/50]
# Training: 100%|██████████| 25/25 [00:06<00:00,  3.57it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000001
# Val MAE: 116.14
# Val RMSE: 124.99
# Val PSNR: 29.28
# Val SSIM: 0.6048
#
# Epoch [20/50]
# Training: 100%|██████████| 25/25 [00:06<00:00,  3.58it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.06it/s]
# Train Loss: 0.000000
# Val MAE: 61.69
# Val RMSE: 66.57
# Val PSNR: 30.34
# Val SSIM: 0.6273
#
# Epoch [21/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.44it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.07it/s]
# Train Loss: 0.000000
# Val MAE: 30.42
# Val RMSE: 42.72
# Val PSNR: 30.73
# Val SSIM: 0.6540
#
# Epoch [22/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.35it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.97it/s]
# Train Loss: 0.000000
# Val MAE: 41.05
# Val RMSE: 48.97
# Val PSNR: 30.77
# Val SSIM: 0.6569
#
# Epoch [23/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.53it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.99it/s]
# Train Loss: 0.000001
# Val MAE: 44.72
# Val RMSE: 53.14
# Val PSNR: 30.64
# Val SSIM: 0.6591
#
# Epoch [24/50]
# Training: 100%|██████████| 25/25 [00:06<00:00,  3.65it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.94it/s]
# Train Loss: 0.000000
# Val MAE: 48.62
# Val RMSE: 54.77
# Val PSNR: 30.75
# Val SSIM: 0.6578
#
# Epoch [25/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.52it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.04it/s]
# Train Loss: 0.000000
# Val MAE: 36.13
# Val RMSE: 44.16
# Val PSNR: 30.90
# Val SSIM: 0.6664
#
# Epoch [26/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.52it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.97it/s]
# Train Loss: 0.000000
# Val MAE: 46.72
# Val RMSE: 52.58
# Val PSNR: 30.80
# Val SSIM: 0.6618
#
# Epoch [27/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.42it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.00it/s]
# Train Loss: 0.000000
# Val MAE: 50.41
# Val RMSE: 56.31
# Val PSNR: 30.79
# Val SSIM: 0.6637
#
# Epoch [28/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.33it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.94it/s]
# Train Loss: 0.000000
# Val MAE: 41.76
# Val RMSE: 51.90
# Val PSNR: 30.74
# Val SSIM: 0.6684
#
# Epoch [29/50]
# Training: 100%|██████████| 25/25 [00:06<00:00,  3.57it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.97it/s]
# Train Loss: 0.000001
# Val MAE: 52.09
# Val RMSE: 60.45
# Val PSNR: 30.65
# Val SSIM: 0.5911
#
# Epoch [30/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.45it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.93it/s]
# Train Loss: 0.000000
# Val MAE: 20.81
# Val RMSE: 36.12
# Val PSNR: 31.15
# Val SSIM: 0.6824
#
# Epoch [31/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.47it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.96it/s]
# Train Loss: 0.000000
# Val MAE: 45.31
# Val RMSE: 50.95
# Val PSNR: 31.00
# Val SSIM: 0.6755
#
# Epoch [32/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.34it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.00it/s]
# Train Loss: 0.000001
# Val MAE: 63.06
# Val RMSE: 66.77
# Val PSNR: 30.75
# Val SSIM: 0.6564
#
# Epoch [33/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.47it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.02it/s]
# Train Loss: 0.000000
# Val MAE: 23.40
# Val RMSE: 34.62
# Val PSNR: 31.22
# Val SSIM: 0.6832
#
# Epoch [34/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.42it/s]
# Validating: 100%|██████████| 316/316 [00:40<00:00,  7.79it/s]
# Train Loss: 0.000000
# Val MAE: 21.93
# Val RMSE: 35.43
# Val PSNR: 31.27
# Val SSIM: 0.6911
#
# Epoch [35/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.36it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.94it/s]
# Train Loss: 0.000000
# Val MAE: 62.93
# Val RMSE: 67.38
# Val PSNR: 30.79
# Val SSIM: 0.6668
#
# Epoch [36/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.57it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.96it/s]
# Train Loss: 0.000000
# Val MAE: 30.95
# Val RMSE: 39.88
# Val PSNR: 31.30
# Val SSIM: 0.6909
#
# Epoch [37/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.22it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.04it/s]
# Train Loss: 0.000000
# Val MAE: 45.33
# Val RMSE: 49.97
# Val PSNR: 31.10
# Val SSIM: 0.6833
#
# Epoch [38/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.26it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  7.97it/s]
# Train Loss: 0.000001
# Val MAE: 44.76
# Val RMSE: 53.77
# Val PSNR: 31.06
# Val SSIM: 0.6902
#
# Epoch [39/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.40it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.00it/s]
# Train Loss: 0.000000
# Val MAE: 18.81
# Val RMSE: 28.89
# Val PSNR: 31.32
# Val SSIM: 0.6964
#
# Epoch [40/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.26it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 20.66
# Val RMSE: 31.95
# Val PSNR: 31.41
# Val SSIM: 0.6895
#
# Epoch [41/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.56it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.04it/s]
# Train Loss: 0.000001
# Val MAE: 36.47
# Val RMSE: 46.05
# Val PSNR: 31.17
# Val SSIM: 0.6951
#
# Epoch [42/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.48it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.06it/s]
# Train Loss: 0.000000
# Val MAE: 22.32
# Val RMSE: 33.04
# Val PSNR: 31.48
# Val SSIM: 0.7029
#
# Epoch [43/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.49it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 54.35
# Val RMSE: 66.08
# Val PSNR: 31.07
# Val SSIM: 0.6962
#
# Epoch [44/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.53it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.03it/s]
# Train Loss: 0.000000
# Val MAE: 62.67
# Val RMSE: 67.94
# Val PSNR: 30.96
# Val SSIM: 0.6836
#
# Epoch [45/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.41it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.03it/s]
# Train Loss: 0.000001
# Val MAE: 164.18
# Val RMSE: 169.54
# Val PSNR: 29.24
# Val SSIM: 0.5476
#
# Epoch [46/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.56it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.02it/s]
# Train Loss: 0.000000
# Val MAE: 99.82
# Val RMSE: 102.99
# Val PSNR: 30.34
# Val SSIM: 0.6029
#
# Epoch [47/50]
# Training: 100%|██████████| 25/25 [00:06<00:00,  3.61it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 96.91
# Val RMSE: 102.02
# Val PSNR: 30.52
# Val SSIM: 0.6465
#
# Epoch [48/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.50it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.05it/s]
# Train Loss: 0.000000
# Val MAE: 67.01
# Val RMSE: 70.20
# Val PSNR: 31.00
# Val SSIM: 0.6656
#
# Epoch [49/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.42it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.04it/s]
# Train Loss: 0.000000
# Val MAE: 62.71
# Val RMSE: 70.69
# Val PSNR: 31.07
# Val SSIM: 0.7055
#
# Epoch [50/50]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.47it/s]
# Validating: 100%|██████████| 316/316 [00:39<00:00,  8.06it/s]
# Train Loss: 0.000000
# Val MAE: 16.33
# Val RMSE: 27.27
# Val PSNR: 31.69
# Val SSIM: 0.7128

# %%
import pandas as pd

results_df = pd.DataFrame([best_results])
results_df.to_csv("results/csrnet_metrics.csv", index=False)

print("Saved results.")
# Out:
# Saved results.

# %%
import shutil

shutil.copy(
    "checkpoints/csrnet/best_model.pth",
    "/kaggle/working/csrnet_best_model.pth"
)

print("Checkpoint copied to working directory.")
# Out:
# Checkpoint copied to working directory.

# %%
from src.utils.visualization import visualize_predictions

fixed_indices = [165, 173, 33, 78, 93]

visualize_predictions(
    model,
    test_dataset,
    device,
    save_dir="results/qualitative_results/csrnet",
    indices=fixed_indices
)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Saved visualizations to results/qualitative_results/csrnet
