# %%
# !git clone https://github.com/riyamaurya86/crowd-counting-partB.git
# Out:
# Cloning into 'crowd-counting-partB'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 38 (delta 6), reused 38 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 5.29 KiB | 1.32 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !git clone https://github.com/riyamaurya86/crowd-counting-partB.git
# Out:
# Cloning into 'crowd-counting-partB'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 38 (delta 6), reused 38 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 5.29 KiB | 1.32 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd crowd-counting-partB
# Out:
# /kaggle/working/crowd-counting-partB

# %%
import os
import torch
from torch.utils.data import DataLoader

from src.datasets.shanghai_partb import ShanghaiPartBDataset
from src.models.cnn import CNNBaseline
from src.engine.trainer import train_one_epoch, validate, save_checkpoint
from src.losses.mse import get_mse_loss
from src.utils.seed import set_seed

# %%
set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
dataset_path = "/kaggle/input/datasets/tthien/shanghaitech-with-people-density-map/ShanghaiTech/part_B"

train_dataset = ShanghaiPartBDataset(dataset_path, mode="train", crop_size=256)
test_dataset = ShanghaiPartBDataset(dataset_path, mode="test")

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=2)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))
# Out:
# Train size: 400
# Test size: 316

# %%
model = CNNBaseline().to(device)

criterion = get_mse_loss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
num_epochs = 20
best_mae = float("inf")

os.makedirs("checkpoints/cnn", exist_ok=True)

for epoch in range(num_epochs):
    print(f"\nEpoch [{epoch+1}/{num_epochs}]")

    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_results = validate(model, test_loader, criterion, device)

    print(f"Train Loss: {train_loss:.6f}")
    print(f"Val MAE: {val_results['mae']:.2f}")
    print(f"Val RMSE: {val_results['rmse']:.2f}")
    print(f"Val PSNR: {val_results['psnr']:.2f}")
    print(f"Val SSIM: {val_results['ssim']:.4f}")

    # Save best model
    if val_results["mae"] < best_mae:
        best_mae = val_results["mae"]
        best_results = val_results.copy()
        save_checkpoint(
            model,
            optimizer,
            epoch,
            best_mae,
            "checkpoints/cnn/best_model.pth"
        )
# Out:
# Epoch [1/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.27it/s]
# Validating: 100%|██████████| 316/316 [00:37<00:00,  8.53it/s]
# Train Loss: 0.000001
# Val MAE: 179.77
# Val RMSE: 209.07
# Val PSNR: 27.65
# Val SSIM: 0.4425
#
# Epoch [2/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.22it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.81it/s]
# Train Loss: 0.000001
# Val MAE: 73.72
# Val RMSE: 107.87
# Val PSNR: 28.48
# Val SSIM: 0.5449
#
# Epoch [3/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.29it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.84it/s]
# Train Loss: 0.000000
# Val MAE: 75.77
# Val RMSE: 114.12
# Val PSNR: 28.81
# Val SSIM: 0.5678
#
# Epoch [4/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.44it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.88it/s]
# Train Loss: 0.000000
# Val MAE: 68.55
# Val RMSE: 105.19
# Val PSNR: 28.97
# Val SSIM: 0.5816
#
# Epoch [5/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.14it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.87it/s]
# Train Loss: 0.000001
# Val MAE: 67.48
# Val RMSE: 96.60
# Val PSNR: 28.91
# Val SSIM: 0.5780
#
# Epoch [6/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.32it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.83it/s]
# Train Loss: 0.000000
# Val MAE: 68.92
# Val RMSE: 94.81
# Val PSNR: 28.91
# Val SSIM: 0.5787
#
# Epoch [7/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.37it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.85it/s]
# Train Loss: 0.000001
# Val MAE: 74.51
# Val RMSE: 96.33
# Val PSNR: 28.78
# Val SSIM: 0.5692
#
# Epoch [8/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.30it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.84it/s]
# Train Loss: 0.000001
# Val MAE: 77.55
# Val RMSE: 115.86
# Val PSNR: 29.32
# Val SSIM: 0.5994
#
# Epoch [9/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.37it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.81it/s]
# Train Loss: 0.000001
# Val MAE: 65.03
# Val RMSE: 101.64
# Val PSNR: 29.35
# Val SSIM: 0.6128
#
# Epoch [10/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.27it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.84it/s]
# Train Loss: 0.000000
# Val MAE: 61.66
# Val RMSE: 93.30
# Val PSNR: 29.31
# Val SSIM: 0.6160
#
# Epoch [11/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.36it/s]
# Validating: 100%|██████████| 316/316 [00:36<00:00,  8.75it/s]
# Train Loss: 0.000000
# Val MAE: 73.46
# Val RMSE: 111.71
# Val PSNR: 29.45
# Val SSIM: 0.6067
#
# Epoch [12/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.35it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.82it/s]
# Train Loss: 0.000000
# Val MAE: 86.69
# Val RMSE: 123.43
# Val PSNR: 29.49
# Val SSIM: 0.5993
#
# Epoch [13/20]
# Training: 100%|██████████| 25/25 [00:08<00:00,  3.11it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.86it/s]
# Train Loss: 0.000001
# Val MAE: 61.36
# Val RMSE: 90.92
# Val PSNR: 29.33
# Val SSIM: 0.6220
#
# Epoch [14/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.13it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.81it/s]
# Train Loss: 0.000001
# Val MAE: 59.80
# Val RMSE: 93.27
# Val PSNR: 29.44
# Val SSIM: 0.6251
#
# Epoch [15/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.16it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.79it/s]
# Train Loss: 0.000000
# Val MAE: 64.07
# Val RMSE: 88.76
# Val PSNR: 29.28
# Val SSIM: 0.6185
#
# Epoch [16/20]
# Training: 100%|██████████| 25/25 [00:08<00:00,  3.10it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.87it/s]
# Train Loss: 0.000001
# Val MAE: 59.17
# Val RMSE: 93.68
# Val PSNR: 29.45
# Val SSIM: 0.6173
#
# Epoch [17/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.29it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.84it/s]
# Train Loss: 0.000001
# Val MAE: 90.66
# Val RMSE: 124.45
# Val PSNR: 29.44
# Val SSIM: 0.5711
#
# Epoch [18/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.28it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.81it/s]
# Train Loss: 0.000000
# Val MAE: 75.45
# Val RMSE: 94.01
# Val PSNR: 29.00
# Val SSIM: 0.5941
#
# Epoch [19/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.39it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.85it/s]
# Train Loss: 0.000001
# Val MAE: 69.75
# Val RMSE: 90.03
# Val PSNR: 29.09
# Val SSIM: 0.6103
#
# Epoch [20/20]
# Training: 100%|██████████| 25/25 [00:07<00:00,  3.37it/s]
# Validating: 100%|██████████| 316/316 [00:35<00:00,  8.86it/s]
# Train Loss: 0.000001
# Val MAE: 61.45
# Val RMSE: 97.92
# Val PSNR: 29.49
# Val SSIM: 0.6030

# %%
import pandas as pd

results_df = pd.DataFrame([best_results])
results_df.to_csv("results/cnn_metrics.csv", index=False)

print("Saved results.")
# Out:
# Saved results.

# %%
import shutil

shutil.copy(
    "checkpoints/cnn/best_model.pth",
    "/kaggle/working/cnn_best_model.pth"
)

print("Checkpoint copied to working directory.")
# Out:
# Checkpoint copied to working directory.

# %%
print("Best MAE saved:", checkpoint["best_mae"])
# Out:
# Best MAE saved: 59.166555041753796

# %%
model = CNNBaseline().to(device)

checkpoint = torch.load(
    "checkpoints/cnn/best_model.pth",
    map_location=device
)

model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

print("Checkpoint loaded successfully.")

# %%
from src.utils.visualization import visualize_predictions

fixed_indices = [165, 173, 33, 78, 93]

visualize_predictions(
    model,
    test_dataset,
    device,
    save_dir="results/qualitative_results/cnn",
    indices=fixed_indices
)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Saved visualizations to results/qualitative_results/cnn
